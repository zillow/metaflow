# %% [markdown]
# # What is Jupyter Lab
# * Interactive, browser-based computing and development environment
# * Exploratory data science, ML, visualization, analysis, stats
# * Reproducible document format

# %% [markdown]
# ![image.png](attachment:d9875aa6-0ea7-4069-83ee-63589189762a.png)

# %% [markdown]
# ## Run a cell
# * shift+enter
# * click play button above

# %%
1 + 3
# Out:
# 4

# %% [markdown]
# ### Access a variable declared earlier

# %%
x = "juneteenth"

# %%
len(x)
# Out:
# 10

# %% [markdown]
# # Window Management
# - open another window (`ui.ipynb`) -> becomes a tab
# - drag and place it below
#
#
#
# ![image.png](attachment:f021a446-8fec-454e-b809-6b696159db3b.png)
